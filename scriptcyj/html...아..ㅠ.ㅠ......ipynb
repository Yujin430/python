# %%
import urllib2
source = urllib2.urlopen("http://cse.kut.ac.kr").read()
#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
import sgmllib,string

class Stripper(sgmllib.SGMLParser):
    def __init__(self):
        self.data = []
        sgmllib.SGMLParser.__init__(self)
    def unknown_starttag(self,tag,attrib):
        self.data.append(" ")
    def unkonwn_endtag(self, tag):
        self.data.append(" ")
    def handle_data(self,data):
        self.data.append(data)
    def gettext(self):
        test = string.join(self.data,"")
        return string.join(string.split(text))

def StripTag(text):
    s= Stripper()
    s.feed(text)
    s.close()
    return s.gettext()
yap= StripTag(source)
print type(yap)
print yap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-65dd93c499d7> in <module>()
#      23     s.close()
#      24     return s.gettext()
# ---> 25 yap= StripTag(source)
#      26 print type(yap)
#      27 print yap
#
# <ipython-input-1-65dd93c499d7> in StripTag(text)
#      22     s.feed(text)
#      23     s.close()
# ---> 24     return s.gettext()
#      25 yap= StripTag(source)
#      26 print type(yap)
#
# <ipython-input-1-65dd93c499d7> in gettext(self)
#      16     def gettext(self):
#      17         test = string.join(self.data,"")
# ---> 18         return string.join(string.split(text))
#      19
#      20 def StripTag(text):
#
# NameError: global name 'text' is not defined

# %%
import urllib2
source = urllib2.urlopen("http://cse.kut.ac.kr").read()
#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것


str='하하< label for="keep_signed" >로그인 유지< /label ><><><>얍<><>'
source = replaceAll("<[^>]*>","")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-772d92b43553> in <module>()
#       5
#       6 str='하하< label for="keep_signed" >로그인 유지< /label ><><><>얍<><>'
# ----> 7 source = replaceAll("<[^>]*>","")
#
# NameError: name 'replaceAll' is not defined

# %%
import urllib2
source = urllib2.urlopen("http://cse.kut.ac.kr").read()
#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것

import xml.etree
def remove_tags(str):
    ''.join(xml.etree.ElementTree.fromstring(str).itertext())

str='하하< label for="keep_signed" >로그인 유지< /label ><><><>얍<><>'
remove_tags(source)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-761dfe98f13e> in <module>()
#       8
#       9 str='하하< label for="keep_signed" >로그인 유지< /label ><><><>얍<><>'
# ---> 10 remove_tags(source)
#
# <ipython-input-3-761dfe98f13e> in remove_tags(str)
#       5 import xml.etree
#       6 def remove_tags(str):
# ----> 7     ''.join(xml.etree.ElementTree.fromstring(str).itertext())
#       8
#       9 str='하하< label for="keep_signed" >로그인 유지< /label ><><><>얍<><>'
#
# AttributeError: 'module' object has no attribute 'ElementTree'

# %%
import urllib2
source = urllib2.urlopen("http://cse.kut.ac.kr").read()
print source
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!-- META -->
# <meta charset="utf-8">
# <meta name="Generator" content="XpressEngine">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <!-- TITLE -->
# <title>컴퓨터공학부</title>
# <!-- CSS -->
# <link rel="stylesheet" href="/common/css/xe.min.css?20150910092654" />
# <link rel="stylesheet" href="/layouts/cse/style/prettyPhoto.css?20150805222706" />
# <link rel="stylesheet" href="/layouts/cse/style/stylemobile.css?20150805222706" />
# <link rel="stylesheet" href="/layouts/cse/style/mobilenavigation.css?20150805222706" />
# <link rel="stylesheet" href="/modules/editor/styles/ckeditor_light/style.css?20150910092713" />
# <link rel="stylesheet" href="/widgets/login_info/skins/cse_login_info_2015/default.login.css?20150420232234" />
# <link rel="stylesheet" href="/widgets/content_cse/skins/cse_latest_2015/css/widget.css?20150625005943" />
# <link rel="stylesheet" href="/addons/font_nanum_gothic/font-nanum_gothic.css?20150429141819" />
# ...

# %%
import urllib2
source = urllib2.urlopen("http://cse.kut.ac.kr").read()
#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것

import re
def remove_tags(str):
     cleaner = re.compile('<.*?>')
#     cleaner = re.compile('//<!.*?>')
     cleantext=re.sub(cleaner,' ',str)
     return cleantext

        

str='하하< label for="keep_signed" >로그인 유지< /label ><><><>얍<><>'
word=remove_tags(source)
#print type(word)
#print word
#print type(word[1])
wordlist=[]
wordlist.extend(word.split())
for i in range(0,len(wordlist)):
    print "%s" % wordlist[i]
# Out:
# 컴퓨터공학부
# //<![CDATA[
# var
# current_url
# =
# "https://cse.kut.ac.kr/";
# var
# request_uri
# =
# "https://cse.kut.ac.kr/";
# var
# current_mid
# =
# "home_2015";
# var
# waiting_message
# =
# "서버에
# 요청
# 중입니다.
# 잠시만
# 기다려주세요.";
# var
# ssl_actions
# =
# new
# Array();
# var
# default_url
# =
# "https://cse.koreatech.ac.kr/";
# var
# enforce_ssl
# =
# true;xe.current_lang
# =
# "ko";
# xe.cmd_find
# =
# "찾기";
# xe.cmd_cancel
# =
# "취소";
# xe.cmd_confirm
# =
# "확인";
# xe.msg_no_root
# =
# "루트는
# 선택
# 할
# 수
# 없습니다.";
# xe.msg_no_shortcut
# =
# "바로가기는
# 선택
# 할
# 수
# 없습니다.";
# xe.msg_select_menu
# =
# "대상
# 메뉴
# 선택";
# //]]>
# Schoolfun
# -
# Study
# and
# Fun
# <!--
# -->
# 로그인
# 로그인
# 아이디
# 비밀번호
# 로그인
# 유지
# 브라우저를
# 닫더라도
# 로그인이
# 계속
# 유지될
# 수
# 있습니다.
# 로그인
# 유지
# 기능을
# 사용할
# 경우
# 다음
# 접속부터는
# 로그인할
# 필요가
# 없습니다.
# 단,
# 게임방,
# 학교
# 등
# 공공장소에서
# 이용
# 시
# 개인정보가
# 유출될
# 수
# 있으니
# 꼭
# 로그아웃을
# 해주세요.
# 회원가입
# ID/PW
# 찾기
# IT
# 교육의
# 글로벌
# 메카!
# 한국기술교육대학교
# 컴퓨터공학부
# Close
# 소개
# 구성원소개
# 학사안내
# ...

# %%
str='하하< label for="keep_signed" >로그인 유지< /label ><><><>얍<><>'
number=len(str)
test=''
wordlist=[]
for i in range(0,number):
    if((i!=number-1) and (str[i]=='>')):
        j=i
        while(str[j]!='<'):
            j+=1
        text=str[i+1:j]
        i=j
        wordlist.extend(text.split())
print unicode(wordlist)
for i in range (0,len(wordlist)):
    print "%s" % wordlist[i]
# Out:
# ['\xeb\xa1\x9c\xea\xb7\xb8\xec\x9d\xb8', '\xec\x9c\xa0\xec\xa7\x80', '\xec\x96\x8d']
# 로그인
# 유지
# 얍

# %%
import urllib2
source = urllib2.urlopen("http://cse.kut.ac.kr").read()
#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
number=len(source)
print number
test=''
wordlist=[]
for i in range(0,number):
    if((source[i]=='>') and (i!=number-1)):
        j=i+1
        while((source[j]!='<') and (j<number-1)):
            j+=1
            #print source[j]
        text=source[i+1:j]
        wordlist.extend(text.split())
        i=j
for i in range(0,len(wordlist)):
    print wordlist[i],
# Out:
# 36214
# ...

# %%
import urllib2
source = urllib2.urlopen("http://www.naver.com/").read()
#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
for i in range(0, source.count('<!--')):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")
#print source
for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:],"")
#print source
words = source.split()
#for word in words:
    #print word
print len(words)
# Out:
# 5010

# %%
import urllib2
import string
# -*-coding:utf-8 -*-


source=urllib2.urlopen("http://www.naver.com").read()
#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
for i in range(0, source.count('<!--')):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")
#print source
for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:],"")
print source
# Out:
# NAVER
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# //
#
#
# var isLogin = false;
# var global = {
# isSupportedFlicking : false,
# isIPAD : false
# };
# var strHost = "www.naver.com";
# var isMobile = false;
# var isMyCast = false;
# var svr = "";
# var LogError=function(b){var a=new Image();a.src="http://cecs.naver.com/?m="+b+"&u="+document.location+"&l=1115"};DLScript={quSXI:new Array(),quS:new Array(),retry:0,isLoad:function(a){for(var b=this.quS.length-1;
# b>=0;b--){if(this.quS[b]===a){return true}}return false},_runOnload:function(b,d,c){if(!d){return}var a=b.readyState;if(typeof a==="undefined"&&!b.onloadDone){b.onloadDone=true;(c)?setTimeout(d,100):b.onload=d;
# return}if(("loaded"===a||"complete"===a)&&!b.onloadDone){b.onloadDone=true;setTimeout(d,100)}else{if(this.retry<10){this.retry++;setTimeout(function(){DLScript._runOnload(b,d,c)},10)}}},_createJSDom:function(c,b){var a=document.createElement("script");
# ...

# %%
import urllib2
source = urllib2.urlopen("http://www.naver.com").read()
print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
number=len(source)
test=''
wordlist=[]
for i in range(0,number):
    if(i==0 and source[i]!='<'):
        j=i
        while((source[j]!='<') and (j<number-1)):
            j+=1
        text=source[i:j]
        wordlist.extend(text.split())
        i=j
    elif((source[i]=='<') and (i!=number-1)):
        j=i+1
        while((source[j]!='>') and (source[j+1]!='=') and (j<number-1)):
            j+=1
        i=j
    elif((source[i]=='>') and (i!=number-1)):
        j=i+1
        while((source[j]!='<') and (j<number-1)):
            j+=1
        text=source[i+1:j]
        if('-->' not in text):
            wordlist.extend(text.split())
        i=j
for i in range(0,len(wordlist)):
    print wordlist[i],
# Out:
# <!doctype html>
# <html lang="ko">
# <head>
# <meta charset="utf-8">
# <meta http-equiv="Content-Script-Type" content="text/javascript">
# <meta http-equiv="Content-Style-Type" content="text/css">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=960">
# <meta name="apple-mobile-web-app-title" content="NAVER" />
# <meta property="og:title" content="네이버 메인">
# <meta property="og:url" content="http://www.naver.com/">
# <meta property="og:image" content="http://static.naver.net/www/mobile/edit/2015/0429/mobile_20514817711.png">
# <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요">
# <meta name="twitter:card" content="summary">
# <meta name="twitter:title" content="네이버 메인">
# <meta name="twitter:url" content="http://www.naver.com/">
# <meta name="twitter:image" content="http://static.naver.net/www/mobile/edit/2015/0429/mobile_20514817711.png">
# ...
